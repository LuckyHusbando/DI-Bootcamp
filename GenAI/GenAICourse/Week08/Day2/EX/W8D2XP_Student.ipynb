# %% [markdown]
# # Exercises XP: Student Notebook
#
# For each exercise, the **Instructions** from the plateform are guided, and the **Guidance** explains exactly what you must do to complete the task.

# %% [markdown]
# ## What you will learn
# - How to clearly define and articulate a machine learning problem statement.
#
# - The process of data collection, including identifying relevant data types and potential data sources.
# Skills in feature selection and justification for machine learning models, particularly in the context of loan default prediction.
#
# - Understanding of different types of machine learning models and their suitability for various real-world scenarios.
#
# - Techniques and strategies for evaluating the performance of different machine learning models, including choosing appropriate metrics and understanding their implications.

# %% [markdown]
# ## What you will create
# - A detailed problem statement and data collection plan for a loan default prediction project, including identification of key data types and sources.
# - A comprehensive feature selection analysis for a hypothetical loan default prediction dataset.
# - A theoretical evaluation strategy for three different types of machine learning models, addressing the unique challenges and metrics relevant to each model type.
# - Thoughtful analyses and justifications for choosing specific machine learning approaches for varied scenarios such as stock price prediction, library organization, and robot navigation.
# - A document or presentation that showcases your understanding and approach to evaluating and optimizing machine learning models in diverse contexts.

# %% [markdown]
# ## 🌟 Exercise 1 : Defining the Problem and Data Collection for Loan Default Prediction
#
# ### Instructions
# - Write a clear problem statement for predicting loan defaults.
# - Identify and list the types of data you would need for this project (e.g., personal details of applicants, credit scores, loan amounts, repayment history).
# - Discuss the sources where you can collect this data (e.g., financial institution’s internal records, credit bureaus).
#
# **Expected Output:** A document detailing the problem statement and a comprehensive plan for data collection, including data types and sources.

# %% [markdown]
# ### Guidance
# - Please write your answer as a short document. Begin by stating the prediction objective in a complete sentence that names the target variable and the decision it will support. Then, describe the data types you would collect in complete sentences. For each data type, explain in one sentence why it could help predict loan defaults.
#
# - After that, name realistic data sources in complete sentences, and briefly describe how you would obtain or integrate each source.
#
# - Finally, include one paragraph that explains risks and constraints such as privacy, regulation, data quality, sampling bias, and governance.

# %% [markdown]
# ### Your answer
#
# #Problem Statement
#
# The objective of this project is to predict the likelihood of loan defaults—where the target variable is a
# binary indicator of whether a borrower will fail to repay their loan—in order to support risk assessment
# and loan approval decisions by the institution.
# Required Data Types
# Personal and demographic details: We will collect applicant data such as age, employment status,
# and housing status. These variables help predict defaults by providing context on the applicant's
# overall financial stability and earning capacity.
# Credit history and scores: We will collect historical credit records, including standard credit scores
# and past delinquency events. This data type is crucial because an applicant's past borrowing and
# repayment behavior is a strong indicator of their future financial reliability.
# Loan characteristics: We will gather the specific details of the requested loan, including the principal
# amount, interest rate, term length, and stated loan purpose. These details help assess whether the
# specific debt burden is manageable for the borrower given their current financial situation.
# Financial and banking behavior: We will track existing debt-to-income ratios, current account
# balances, and recurring monthly expenses. This information reveals the day-to-day liquidity and
# existing financial obligations that might constrain the applicant's ability to meet new repayment
# schedules.
# Data Sources and Integration
# Internal Institution Records: We will source historical application and performance data directly
# from internal CRM and loan origination systems. This source will be integrated by constructing
# automated Python data pipelines to extract, clean, and aggregate the relevant records directly from
# our internal PostgreSQL databases.
# External Credit Bureaus: We will rely on major credit reporting agencies to provide standardized
# credit histories and risk scores. This data will be obtained via secure API integrations during the
# application process to pull real-time credit reports directly into our evaluation environment.
# Alternative Data Providers: We will utilize third-party open banking APIs to access utility payment
# histories and granular transaction records. These sources can be integrated by securely querying
# external endpoints, assuming explicit applicant consent, to enrich the financial profiles of individuals
# with thin traditional credit files.
#
# Risks and Constraints
#
# When undertaking this predictive modeling project, several risks and constraints must be carefully
# managed to ensure compliance and model validity. Strict adherence to privacy regulations is
# mandatory to protect sensitive financial data and avoid severe legal penalties. Furthermore, models
# must be meticulously scrutinized for sampling bias, ensuring they do not inadvertently discriminate
# against underrepresented demographic groups and violate fair lending laws. Data quality issues,
# such as missing values, duplicated entries, or outdated credit reports, can significantly degrade the
# accuracy of the model's predictions. Finally, robust data governance frameworks must be
# established to track data lineage, secure access controls, and maintain the integrity and
# transparency of the predictive algorithms used in production.

# %% [markdown]
# ## 🌟 Exercise 2 : Feature Selection and Model Choice for Loan Default Prediction
#
# ### Instructions
# From this dataset, identify which features might be most relevant for predicting loan defaults.
# Justify your choice of features.

# %% [markdown]
# ### Guidance
# - First, identify the features that you believe are most relevant, and write their names in a sentence.
# Then, provide a justification in complete sentences that explains how each selected feature relates to the likelihood of default.
#
# - If you decide to exclude common features, write one sentence for each excluded feature to explain why it is not appropriate in this context.
#
# - Conclude with two complete sentences that explain how you would encode categorical features and how you would impute missing values.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It provides a simple template you can modify while writing your justification.

import pandas as pd

# This placeholder DataFrame allows the cell to run even if you did not load a dataset yet.
example_columns = [
    "age","employment_length","annual_income","credit_score","loan_amount","interest_rate",
    "debt_to_income","num_delinquencies","num_open_accounts","total_utilization","home_ownership",
    "purpose","term","application_type","state","zip_code"
]
df = pd.DataFrame(columns=example_columns)

# Please replace this list with the actual columns that you select.
selected_features = [
    # e.g., "credit_score","debt_to_income","annual_income","loan_amount","interest_rate",
    # "employment_length","num_delinquencies","total_utilization"
]

print("You will now justify the selected features in complete sentences below.")
# Out:
# You will now justify the selected features in complete sentences below.

# %% [markdown]
# ### Your justification
#
# #Feature Selection & Justification
#
# The most relevant features for predicting loan defaults in this context are the debt-to-income ratio, credit score, historical payment status, and employment length. The debt-to-income ratio is a critical indicator because it directly measures a borrower's financial capacity to manage additional monthly obligations without becoming overleveraged. A borrower's credit score serves as a standardized, quantified summary of their overall financial reliability and historical risk level. Historical payment status is highly predictive because consistent past delinquencies or late payments often signal an impending inability to meet future loan obligations. Furthermore, employment length relates to the likelihood of default by indicating income stability, as borrowers with longer job tenure generally have more predictable cash flows to service their debt.
#
# #Excluded Features
#
# I chose to exclude the applicant's name because it contains no underlying financial signal and only serves to increase the dimensionality of the dataset unnecessarily. I also excluded gender because leveraging protected demographic classes for credit decisions violates fair lending laws and introduces dangerous algorithmic bias.
#
# #Data Preprocessing
#
# To encode categorical features, I would use one-hot encoding for variables with low cardinality and target encoding for high-cardinality variables to efficiently capture their relationship with the target variable. For missing values, I would impute numerical data using the median to minimize the distortion caused by outliers, while replacing missing categorical data with an "Unknown" class to preserve the potential predictive signal of the missingness itself.

# %% [markdown]
# ## 🌟 Exercise 3 : Training, Evaluating, and Optimizing the Model
#
# ### Instructions
# Which model(s) would you pick for a Loan Prediction ?
# Outline the steps to evaluate the model’s performance, mentioning specific metrics that would be relevant to evaluate the model.

# %% [markdown]
# ### Guidance
# - Begin by naming one or two candidate models in a complete sentence and explain why each model is suitable for this problem.
#
# - Next, describe an evaluation plan in complete sentences that covers the data split, the cross-validation strategy, the metrics you will report, and how you will choose a decision threshold.
#
# - Then, explain in complete sentences how you will address class imbalance using stratification, class weights, or resampling.
#
# - Finally, state in one or two complete sentences how you would iterate on hyperparameters to improve performance while avoiding data leakage.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It demonstrates standard classification metrics for binary loan default prediction.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score, confusion_matrix, classification_report

# Please replace these placeholders with your true labels and predicted probabilities.
y_true = [0,1,0,1,0,0,1,0,1,0]            # placeholder labels
y_pred_proba = [0.05,0.80,0.10,0.65,0.20,0.15,0.70,0.30,0.85,0.25]  # placeholder probabilities

# You should set a decision threshold that reflects the precision–recall trade-off for your business case.
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
print("\nConfusion matrix:\n", confusion_matrix(y_true, y_pred))
print("\nClassification report:\n", classification_report(y_true, y_pred, zero_division=0))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ROC-AUC: 1.0
# PR-AUC (Average Precision): 1.0
#
# Confusion matrix:
#  [[6 0]
#  [0 4]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10

# %% [markdown]
# ### Your answer
#
# XGBoost is an excellent candidate model because it handles non-linear relationships and complex feature interactions exceptionally well, often achieving the highest predictive performance in loan default scenarios. Logistic Regression also serves as a highly suitable alternative because it provides a strong, interpretable baseline that allows stakeholders to easily understand how individual features impact the probability of default.
#
# To evaluate the model's performance, I would first split the dataset into an 80% training set and a 20% hold-out test set. Within the training set, I will use a 5-fold cross-validation strategy to robustly estimate model performance and ensure stability across different data partitions. I will report the ROC-AUC score to measure the model's overall discriminatory power, alongside precision, recall, and the F1-score to specifically track how effectively the model flags actual defaulters.
#
# To choose a final decision threshold, I will analyze the Precision-Recall curve and select a cutoff that balances the business need to maximize the detection of defaults against the opportunity cost of falsely rejecting reliable borrowers.  To address class imbalance, I will rely on stratification during all data splitting steps to ensure the minority default class remains proportionally represented across all training and testing folds. Furthermore, I will pass higher class weights to the model's loss function to penalize false negatives more heavily, which helps the algorithm focus on the minority class without the risk of over-fitting sometimes associated with synthetic resampling.
#
# Finally, I would iterate on hyperparameters using an optimization search strictly confined within the cross-validation folds of the training set. This nested approach guarantees that the 20% hold-out test data is never exposed during the tuning process, thereby completely avoiding data leakage.

# %% [markdown]
# ## 🌟 Exercise 4 : Designing Machine Learning Solutions for Specific Problems
#
# ### Instructions
# For each of these scenario, decide which type of machine learning would be most suitable. Explain.
#
# Predicting Stock Prices : predict future prices
# Organizing a Library of Books : group books into genres or categories based on similarities.
# Program a robot to navigate and find the shortest path in a maze.

# %% [markdown]
# ### Guidance
# Please identify the appropriate machine learning paradigm for each scenario in complete sentences and justify your choice.
#
# For each scenario, write one complete sentence that describes the input data, one complete sentence that describes the output, and one complete sentence that describes the learning signal or objective.

# %% [markdown]
# ### Your answer
#
# Predicting Stock Prices
#
# Supervised learning, specifically regression analysis, would be most suitable for this scenario because the model needs to learn the relationship between historical market trends and a known continuous target variable to forecast future values accurately.
#
# Input Data: The input data consists of historical market variables such as past prices, trading volumes, and macroeconomic indicators.
#
# Output: The output is a continuous numerical prediction representing the expected future price of the targeted stock.
#
# Learning Objective: The learning objective is to minimize the error between the algorithm's predicted prices and the actual historical prices during the training phase.
#
# Organizing a Library of Books
#
# Unsupervised learning, specifically clustering, is the most appropriate approach here because the algorithm must autonomously discover hidden structures and group items based on similarity without relying on pre-labeled genre tags.
#
# Input Data: The input data involves text features extracted from the books, such as plot summaries, keywords, or stylistic text patterns.
#
# Output: The output is the assignment of each book into a distinct, mathematically derived cluster based on its shared characteristics with other texts.
#
# Learning Objective: The learning signal is the optimization of a distance metric, aiming to maximize the similarity of books within the same group while minimizing the similarity between different groups.
#
# Programming a Robot to Navigate a Maze
#
# Reinforcement learning is the ideal choice for this scenario because the algorithm requires an agent to learn a sequence of decisions in a dynamic environment through trial and error, rather than learning from static, pre-collected examples.
#
# Input Data: The input data represents the robot's current state within the maze, which includes environmental sensor readings and its current spatial coordinates.
#
# Output: The output is a specific action or movement chosen from the discrete set of possible directions the robot can travel.
#
# Learning Objective: The learning objective is to maximize the cumulative reward over time by discovering the shortest path to the exit while accumulating penalties for hitting walls or taking unnecessary steps.

# %% [markdown]
# ## 🌟 Exercise 5 : Designing an Evaluation Strategy for Different ML Models
#
# ### Instructions
# - Select three types of machine learning models: one from supervised learning (e.g., a classification model), one from unsupervised learning (e.g., a clustering model), and one from reinforcement learning. - For the supervised model, outline a strategy to evaluate its performance, including the choice of metrics (like accuracy, precision, recall, F1-score) and methods (like cross-validation, ROC curves).
# - For the unsupervised model, describe how you would assess the effectiveness of the model, considering techniques like silhouette score, elbow method, or cluster validation metrics.
# - For the reinforcement learning model, discuss how you would measure its success, considering aspects like cumulative reward, convergence, and exploration vs. exploitation balance.
# - Address the challenges and limitations of evaluating models in each category.

# %% [markdown]
# ### Guidance
# - Please write a separate paragraph for each of the three model categories.
# - In the supervised paragraph, describe your validation plan and list the metrics you will report in complete sentences.
# - In the unsupervised paragraph, explain how you would measure cluster quality or structure in complete sentences and mention any diagnostic plots.
# - In the reinforcement learning paragraph, describe how you would track cumulative reward, assess convergence, and balance exploration and exploitation using complete sentences.
# Conclude with one complete sentence per category that states a key evaluation challenge.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Supervised classification metrics template with placeholders.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score

# Replace these placeholders with your real outputs.
y_true = [0,1,1,0,1,0,0,1,0,1]
y_pred_proba = [0.1,0.7,0.8,0.2,0.6,0.3,0.4,0.9,0.2,0.85]
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ROC-AUC: 1.0
# PR-AUC (Average Precision): 1.0

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Unsupervised clustering metrics template with synthetic data.

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

X, _ = make_blobs(n_samples=300, centers=3, random_state=42)
kmeans = KMeans(n_clusters=3, n_init="auto", random_state=42)
labels = kmeans.fit_predict(X)
sil = silhouette_score(X, labels)
print("Silhouette score (higher is better):", round(sil, 4))

print("Please explain in complete sentences when you would use the elbow method and how you would interpret it.")
# Out:
# Silhouette score (higher is better): 0.848
# Please explain in complete sentences when you would use the elbow method and how you would interpret it.

# %% [markdown]
# ### Your answer
#
# For the supervised learning category, I would select a Random Forest Classifier and evaluate it using a stratified k-fold cross-validation strategy paired with a hold-out test set to ensure the model generalizes well to unseen data. I will report accuracy to gauge overall correctness, alongside precision, recall, and the F1-score to understand the model's specific performance on positive and negative predictions, which is critical if the classes are imbalanced. Additionally, I would plot Receiver Operating Characteristic (ROC) curves and calculate the Area Under the Curve (AUC) to comprehensively assess the model's ability to distinguish between classes across various decision thresholds. A key challenge in evaluating supervised models is that performance metrics can be highly misleading if the data suffers from hidden target leakage or severe, unaddressed class disparities.
#
# For the unsupervised learning category, I would choose K-Means clustering and measure the quality of the resulting cluster structure by calculating the silhouette score to evaluate how similar an object is to its own cluster compared to neighboring clusters. To determine the optimal number of groups and assess the model's effectiveness, I would utilize diagnostic plots such as the Elbow method curve, which plots the within-cluster sum of squares against the number of clusters, alongside silhouette plots to visually inspect the density and separation of each formed group. I would also review internal cluster validation metrics like the Davies-Bouldin index to ensure the clusters are compact and well-separated. A major challenge in evaluating unsupervised models is the inherent subjectivity of the results, as there is no absolute ground truth to definitively confirm that the mathematically discovered patterns are practically meaningful to the business.
#
# For the reinforcement learning category, I would implement a Deep Q-Network (DQN) and measure its success by continuously tracking the moving average of the cumulative reward the agent achieves per training episode. I would assess convergence by monitoring both the stabilization of the neural network's loss function and the flattening of the episode reward curve, which indicates that the agent has learned a near-optimal policy and its performance has plateaued. To ensure robust learning, I would balance exploration and exploitation by utilizing an epsilon-greedy strategy, systematically decaying the exploration rate over time while verifying that the agent still occasionally tries new actions to avoid getting trapped in local optima. A significant limitation when evaluating reinforcement learning models is that achieving high cumulative rewards in a controlled, simulated training environment rarely guarantees safe or successful execution when the agent is deployed in a complex, unpredictable real-world scenario.
