# %%
#Exercise 2

import pandas as pd

# Load the dataset
df_clean_credit = pd.read_csv('clean_dataset.csv')

# Display the first few rows
print("First few rows of clean_dataset.csv:")
print(df_clean_credit.head())

# Get a brief description
print("\nDescription of clean_dataset.csv:")
df_clean_credit.info()

import pandas as pd

# Load the dataset
df_crx = pd.read_csv('crx.csv')

# Display the first few rows
print("First few rows of crx.csv:")
print(df_crx.head())

# Get a brief description
print("\nDescription of crx.csv:")
df_crx.info()

import pandas as pd

# Load the dataset
df_mental_health = pd.read_csv('Mental health Depression disorder Data.csv')

# Display the first few rows
print("First few rows of Mental health Depression disorder Data.csv:")
print(df_mental_health.head())

# Get a brief description
print("\nDescription of Mental health Depression disorder Data.csv:")
df_mental_health.info()

#Exercise 3

# The following columns in clean_dataset.csv are categorized as quantitative or qualitative based on their nature:

# Quantitative Columns: These columns contain numerical data that can be measured or counted.

# Age

# Debt

# YearsEmployed

# CreditScore

# ZipCode

# Income

# Qualitative Columns: These columns represent categories or attributes that cannot be measured numerically.

# Gender

# Married

# BankCustomer

# Industry

# Ethnicity

# PriorDefault

# Employed

# DriversLicense

# Citizen

# Approved

# 2. crx.csv

# The columns in crx.csv are anonymized, so their categorization is based on the data type present in each column.

# Quantitative Columns:

# Column 2 (B): Contains numerical values (e.g., 30.83, 58.67, 24.50).

# Column 3 (C): Contains numerical values (e.g., 0, 4.46, 0.5).

# Column 8 (H): Contains numerical values (e.g., 1.25, 3.04, 1.5).

# Column 11 (K): Contains numerical values (e.g., 01, 06, 0).

# Column 14 (N): Contains numerical values (e.g., 00202, 00043, 00280).

# Column 15 (O): Contains numerical values (e.g., 0, 560, 824).

# Qualitative Columns:

# Column 1 (A): Contains alphabetical data (e.g., b, a).

# Column 4 (D): Contains alphabetical data (e.g., u, u).

# Column 5 (E): Contains alphabetical data (e.g., g, g).

# Column 6 (F): Contains alphabetical data (e.g., w, q).

# Column 7 (G): Contains alphabetical data (e.g., v, h).

# Column 9 (I): Contains alphabetical data (e.g., t, t).

# Column 10 (J): Contains alphabetical data (e.g., t, t).

# Column 12 (L): Contains alphabetical data (e.g., f, f).

# Column 13 (M): Contains alphabetical data (e.g., g, g).

# Column 16 (P): Contains alphabetical data (e.g., +, +).

# 3. Mental health Depression disorder Data.csv

# The following columns in Mental health Depression disorder Data.csv are categorized as quantitative or qualitative based on their nature:

# Quantitative Columns:

# Year

# Schizophrenia (%)

# Bipolar disorder (%)

# Eating disorders (%)

# Anxiety disorders (%)

# Drug use disorders (%)

# Depression (%)

# Alcohol use disorders (%)

# Qualitative Columns:

# index

# Entity

# Code

#Exercise 4

import pandas as pd
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
df_iris = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df_iris['species'] = [iris.target_names[i] for i in iris.target]

# Display the first few rows
print(df_iris.head())

# Quantitative Columns

# Quantitative columns contain numerical data that can be measured or counted. In this dataset, all four feature columns are quantitative:

# sepal length (cm): This is a measurement of the length of the sepal in centimeters. It is a continuous numerical variable.

# sepal width (cm): This is a measurement of the width of the sepal in centimeters. It is also a continuous numerical variable.

# petal length (cm): This is a measurement of the length of the petal in centimeters. It is a continuous numerical variable.

# petal width (cm): This is a measurement of the width of the petal in centimeters. It is a continuous numerical variable.

# Qualitative Columns

# Qualitative columns describe categories or attributes and do not represent a numerical value.

# species: This column contains the names of the flower species (e.g., setosa, versicolor, virginica). The values are categorical labels, which makes it a qualitative column.

#Exercise 5

# Based on the analysis of the clean_dataset.csv file, here are the key findings for the 'Age' and 'Income' columns.

# Quantitative Column Analysis
# Age: The mean age of the applicants is approximately 31.51 years. The median and mode are both 28.46, indicating that the data is skewed to the right. This means that while most applicants are around their late 20s, there are a few older applicants that pull the average age higher.

# Income: The mean income is approximately $1017.39. However, the median is only $5.00, and the mode is $0.00. This large discrepancy suggests that the income data is highly skewed, with a majority of applicants having very little to no reported income, while a few have extremely high incomes, which pulls the average up.

# Data Visualization
# The following plots provide a visual representation of the distributions for the 'Age' and 'Income' columns.

# Age Distribution
# The histogram for Age shows a right-skewed distribution. The highest frequency of applicants falls within the 20-30 age range, with frequencies decreasing as age increases. This confirms our statistical findings that the majority of applicants are relatively young.

# Income Distribution
# The histogram for Income shows a strong concentration of applicants with an income of $0.00, which is consistent with the mode. A large number of applicants also have low incomes, while there are a few outliers with very high incomes. This confirms the large skewness indicated by the statistical measures.

#Exercise 6

import pandas as pd

# Load the dataset
df_sleep = pd.read_csv('How Much Sleep Do Americans.zip/How Much Sleep Do Americans/Time Americans Spend Sleeping.csv')

# Display the first few rows and column information
print("First five rows of the dataset:")
print(df_sleep.head())
print("\nColumn information:")
df_sleep.info()

# Based on the structure of the dataset, several columns are particularly interesting for specific types of analysis:

# 1. Trend Analysis
# Columns: Year and Avg hrs per day sleeping

# Reasoning: The Year column represents a timeline, while Avg hrs per day sleeping is a quantitative measure of the average amount of sleep. By plotting Avg hrs per day sleeping against Year, you can visualize and analyze the trends in sleep patterns among Americans over time. This could reveal whether the average sleep duration has increased, decreased, or remained stable.

# 2. Group Comparison
# Columns: Age Group, Sex, and Avg hrs per day sleeping

# Reasoning: The Age Group and Sex columns are qualitative categories that allow you to compare sleep patterns across different demographics. You can use these columns to:

# Compare the average hours of sleep between males and females (Sex).

# Analyze how sleep duration varies across different age groups (Age Group), such as "15 to 24 years" versus "65 years and over."

# Conduct a more detailed comparison by grouping the data by both Age Group and Sex to see if there are unique sleep patterns within specific demographic segments.
